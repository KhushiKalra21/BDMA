# %% [markdown]
# <a href="https://colab.research.google.com/github/KhushiKalra21/BDMA/blob/main/Project%201%2B2/KKsg2139_MYSQL_Report_Consumer_Waste_DB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **E-Commerce Consumer Waste Analytics Database**
#
# #  **Project Report**
#
# #  **Consumer Waste Analytics:** Designing and Implementing a Relational Database for Waste Management Insights
#
#
# **By:**
# - Khushi Kalra
# - Saloni Gupta
#
# ## **Project Information**
#
# This project focuses on designing and implementing a relational database system using SQL to analyze customer purchasing behavior, supplier performance, and loyalty trends. The system enables businesses to make data-driven decisions through efficient data storage, retrieval, and analytics.
#
# It involves designing and implementing an **SQL-based relational database** to analyze customer purchasing behavior, supplier performance, and loyalty trends. The goal is to provide **data-driven insights** that help businesses optimize their operations and decision-making.
#
# Unlike traditional waste management tracking, this project **shifts focus to querying and data analytics**, offering a deep dive into **customer retention, supplier efficiency, and revenue trends** through structured SQL queries.
#
# ## **Project Objectives | Problem Statement**
#
# The **Consumer Behavior and Supplier Analytics** project aims to develop an optimized SQL-based database that facilitates tracking customer trends, evaluating supplier efficiency, and improving business decision-making.
#
# The **primary goal** of this project is to **develop and optimize an SQL database** that allows businesses to:
#
# * Design and implement an SQL database schema for e-commerce analytics, including tables for orders, customers, suppliers, and loyalty scores.
# * Analyze customer purchasing patterns to identify high-value customers, frequent buyers, and spending trends for better retention strategies.
# * Evaluate supplier efficiency by tracking order fulfillment rates, return frequencies, and delivery reliability to enhance supply chain management.
# * Segment customers based on loyalty scores and spending behaviors to enable targeted marketing and rewards programs.
# * Detect fraudulent transactions by identifying unusual spending patterns, refund abuse, and bulk purchasing anomalies.
# * Optimize inventory and demand forecasting by tracking fast-selling products and preventing stockouts.
# * Apply indexing, query optimization, and performance tuning techniques to ensure efficient database operations.
# * Generate SQL-driven recommendations to improve customer retention and supplier selection using data insights.
# * Establish a foundation for AI-driven analytics for future customer behavior predictions and supplier performance assessments.
#
# ### **Key Problem Statements:**
#
# 1\) How can SQL queries effectively segment customer behavior and loyalty?
# 2\) What insights can be derived from supplier performance and order fulfillment analysis?
# 3\) How can data be used to detect fraudulent transactions and optimize inventory planning?
# 4\) What indexing and optimization strategies can be applied to improve query performance?
#
# ## **Dataset Information (Dummy Data Used)**
#
# To test the database and validate the effectiveness of SQL queries, a dummy dataset was created and inserted into various tables, including:
#
# * **Customers –** Stores customer details, purchase history, and loyalty scores.
# * **Products –** Contains product information, pricing, and sustainability scores.
# * **Orders –** Logs all customer purchases, including payment methods and order status.
# * **Suppliers –** Tracks supplier details, product supply chains, and performance ratings.
# * **WasteMetrics –** Analyzes product return reasons and environmental impact.
# * **Recommendations –** Generates customer-specific product recommendations based on purchase behavior.
#
# ## **Database Design & Implementation**
#
# * The database consists of multiple relational tables, including **Orders, Products, Customers, Suppliers, LoyaltyScores, and Recommendations**.
# * SQL constraints such as **PRIMARY KEY, FOREIGN KEY, UNIQUE, and CHECK** were used to maintain data integrity.
# * **Normalization techniques** were applied to reduce data redundancy and improve efficiency.
# * **Indexing strategies** were implemented on frequently queried columns to enhance performance.
#
# ## **SQL Queries for Data Analysis**
#
# Key SQL queries were designed for:
#
# 1. **Customer behavior analysis** – Identifying order frequency, total spending, and loyalty trends.
# 2. **Supplier performance evaluation** – Measuring fulfillment rates, return percentages, and delivery delays.
# 3. **Customer loyalty segmentation** – Categorizing customers based on spending behavior and order history.
# 4. **Generating retention recommendations** – Using SQL queries to suggest targeted promotions for high-value customers.
#
# ## **Query Optimization & Performance**
#
# * **EXPLAIN** was used to evaluate query execution plans and optimize slow-performing queries.
# * **Indexes** were created on high-volume data fields to speed up searches and aggregations.
# * **Joins and subqueries** were optimized for efficient data retrieval.
# * **Partitioning and clustering** were considered for large datasets to enhance performance.
#
# ## **Observations & Findings**
#
# ### **1\. Customer Behavior Insights**
#
# * SQL queries helped categorize customers based on **spending, purchase frequency, and loyalty scores**.
# * Identified high-value customers who contribute **significantly to revenue** and should be targeted for loyalty programs.
# * **Frequent returners were flagged**, allowing businesses to investigate dissatisfaction or potential fraud.
#
# ### **2\. Supplier Performance Evaluation**
#
# * Queries revealed which suppliers had **high return rates and delayed order fulfillment**, impacting business operations.
# * Supplier segmentation helped **optimize vendor selection** and contract renegotiations.
#
# ### **3\. Fraud Detection & Risk Analysis**
#
# Queries flagged **suspicious customer activities**, such as:
#
# * Multiple high-value transactions in a short period.
# * Orders from multiple regions using the same account.
# * Frequent returns and refunds, suggesting refund abuse.
#
# Implementing **fraud detection logic** into SQL queries improved risk management and financial security.
#
# ### **4\. Inventory & Demand Forecasting**
#
# * Queries helped predict **fast-moving products** and **items at risk of stockouts**, assisting in inventory planning.
# * **Regional demand analysis** guided better stock distribution and supply chain efficiency.
#
# **Managerial Insights & Business Applications**
#
# 1) **Optimized Customer Retention Strategies**
# * High-value customers should receive **personalized loyalty incentives** based on purchase behavior.
# * **AI-driven recommendation models** can be integrated for targeted marketing.
#
# 1) **Supplier Relationship Management**
# * Businesses should **negotiate better contracts** with underperforming suppliers.
# * Suppliers with high return rates should undergo **quality audits** to ensure product reliability.
#
# 2) **Revenue Protection & Fraud Prevention**
# * **Multi-factor authentication** and purchase validation should be enforced for flagged accounts.
# * Query-driven fraud detection can **reduce revenue loss due to fraudulent activities**.
#
# 3) **Efficient Inventory Planning**
# * Data-driven insights help maintain **optimal stock levels**, avoiding shortages or overstocking.
# * Predictive analytics can **improve demand forecasting**, reducing operational costs.
#
# ## **Recommendations for Improvement**
#
# **Implement More Advanced Query Optimizations**
#
# * Use **materialized views** for frequently queried data.
# * Introduce **partitioning for large datasets** to enhance retrieval speed.
#
# **Integrate Machine Learning for Predictive Analytics**
#
# * AI models can improve fraud detection by analyzing patterns in SQL query outputs.
# * Demand forecasting models can enhance inventory management.
#
# **Enhance Supplier Performance Metrics**
#
# * Additional SQL-based KPIs should track **supplier response times, defect rates, and customer satisfaction scores**.
#
# **Optimize Query Execution & Performance**
#
# * Automate **query indexing** to improve speed.
# * Implement **scheduled database maintenance** to prevent performance degradation.
#
# ### **Limitations of the Study & Challenges Faced**
#
# #### **1\) Handling Complex SQL Queries Efficiently**
#
# **Challenge:** Some queries involving multiple joins and subqueries ran slowly on large datasets.
# **Solution:** Used `EXPLAIN`, indexing, and query restructuring to improve performance.
# **Limitation:** Query execution time can still be high for massive data volumes without partitioning.
#
# #### **2\) Issues with EXPLAIN ANALYZE Query Execution**
#
# **Challenge:** The `EXPLAIN ANALYZE` command did not work on the system, limiting performance diagnostics.
# **Solution:** Used `EXPLAIN` instead to analyze query execution plans and optimize performance.
# **Limitation:** Without `EXPLAIN ANALYZE`, exact execution time and cost estimations were not available.
#
# #### **3\) Simulating Real-World Data with Dummy Records**
#
# **Challenge:** The dummy dataset lacked realistic purchase behavior trends.
# **Solution:** Created diverse test cases representing different business scenarios.
# **Limitation:** Real-world unpredictability still makes accurate forecasting challenging.
#
# #### **4\) Managing Transaction Locks in Multi-User Environments**
#
# **Challenge:** Concurrent queries led to potential locking issues, affecting performance.
# **Solution:** Used `SHOW ENGINE INNODB STATUS` to detect locks and optimized indexing strategies.
# **Limitation:** High-traffic environments may require additional load balancing techniques.
#
# #### **5\) Detecting Fraudulent Behavior Without False Positives**
#
# **Challenge:** Some flagged transactions turned out to be genuine bulk purchases.
# **Solution:** Added multi-layer verification for fraud detection logic.
# **Limitation:** Advanced fraud detection requires integration with behavioral analytics tools.
#
# ## **Conclusion**
#
# This project successfully developed and implemented an **SQL-based database** for analyzing **customer behavior, supplier efficiency, and fraud detection**. The insights derived from SQL queries **enable better decision-making** for marketing, inventory management, and revenue protection.
#
# **Future Enhancements:**
# **→** Implement **AI-driven predictive analytics** for fraud detection and customer retention.
# → Use **real-time transaction monitoring** to detect anomalies dynamically.
# → Optimize queries further using **machine learning-assisted indexing**.
#
# This report demonstrates how SQL can **drive business intelligence and operational efficiency**, transforming raw data into **actionable insights** for e-commerce decision-making.
#
# **SQL Implementation Report: Database Creation and Query Execution**
#
# ## **1\. Database Schema & Table Creation**
#
# ### **Introduction**
#
# This section details the SQL implementation for creating the **Consumer Waste Analytics** database, including the creation of tables, relationships, and constraints. The SQL scripts used for defining the schema ensure data integrity, normalization, and efficient storage.
#
# ### **SQL Code for Database and Table Creation**
#
# #### **Creating the Database**
#
# \-- Creating a new database named 'ConsumerWasteAnalytics'
# CREATE DATABASE ConsumerWasteAnalytics;
#
# \-- Selecting the newly created database for use
# USE ConsumerWasteAnalytics;
#
# #### **Creating Tables**
#
# ##### **Customers Table**
#
# CREATE TABLE Customers (
#     CustomerID INT AUTO\_INCREMENT PRIMARY KEY,
#     Name VARCHAR(100) NOT NULL,
#     Age INT NOT NULL,
#     Region VARCHAR(50),
#     PurchaseHistory TEXT,
#     AverageSpending DECIMAL(10, 2),
#     PreferredCategory VARCHAR(50),
#     LoyaltyScore INT
# );
#
# ##### **Products Table**
#
# CREATE TABLE Products (
#     ProductID INT AUTO\_INCREMENT PRIMARY KEY,
#     Name VARCHAR(100) NOT NULL,
#     Category VARCHAR(50),
#     ReturnRate DECIMAL(5, 2),
#     DisposalRate DECIMAL(5, 2),
#     Price DECIMAL(10, 2),
#     Supplier VARCHAR(100),
#     SustainabilityScore DECIMAL(5, 2\)
# );
#
# ##### **Orders Table**
#
# CREATE TABLE Orders (
#     OrderID INT AUTO\_INCREMENT PRIMARY KEY,
#     CustomerID INT,
#     ProductID INT,
#     OrderDate DATE NOT NULL,
#     ReturnDate DATE,
#     Quantity INT NOT NULL,
#     TotalPrice DECIMAL(10, 2\) NOT NULL,
#     PaymentMethod VARCHAR(50),
#     OrderStatus VARCHAR(50),
#     FOREIGN KEY (CustomerID) REFERENCES Customers(CustomerID),
#     FOREIGN KEY (ProductID) REFERENCES Products(ProductID)
# );
#
# ##### **WasteMetrics Table**
#
# \-- WasteMetrics Table
# CREATE TABLE WasteMetrics (
#     MetricID INT AUTO\_INCREMENT PRIMARY KEY,
#     ProductID INT,
#     ReturnReason TEXT,
#     EnvironmentalImpact TEXT,
#     CarbonFootprint DECIMAL(10, 2),
#     RecyclabilityScore DECIMAL(5, 2),
#     FOREIGN KEY (ProductID) REFERENCES Products(ProductID)
# );
#
# ##### **Recommendations Table**
#
# RecommendationID INT AUTO\_INCREMENT PRIMARY KEY,
#     CustomerID INT,
#     ProductID INT,
#     SuggestedAction TEXT,
#     ActionImpact TEXT,
#     ActionDate DATE,
#     FOREIGN KEY (CustomerID) REFERENCES Customers(CustomerID),
#     FOREIGN KEY (ProductID) REFERENCES Products(ProductID)
# );
#
# ##### **Suppliers Table**
#
# CREATE TABLE Suppliers (
#     SupplierID INT AUTO\_INCREMENT PRIMARY KEY,
#     Name VARCHAR(100) NOT NULL,
#     ContactInfo VARCHAR(200),
#     Region VARCHAR(50),
#     ProductSupplied VARCHAR(255),
#     SupplierRating DECIMAL(3, 2\) CHECK (SupplierRating BETWEEN 0 AND 5\) \-- Rating out of 5
# );
#
# ##### **Inventory Table**
#
# CREATE TABLE Inventory (
#     InventoryID INT AUTO\_INCREMENT PRIMARY KEY,
#     ProductID INT NOT NULL,
#     StockLevel INT NOT NULL,
#     ReorderThreshold INT NOT NULL,
#     StorageLocation VARCHAR(100),
#     RestockDate DATE,
#     SupplierID INT NOT NULL,
#     FOREIGN KEY (ProductID) REFERENCES Products(ProductID),
#     FOREIGN KEY (SupplierID) REFERENCES Suppliers(SupplierID)
# );
#
# ##### **EnvironmentalImpactSummary Table**
#
# CREATE TABLE EnvironmentalImpactSummary (
#     ImpactID INT AUTO\_INCREMENT PRIMARY KEY,
#     ProductID INT NOT NULL,
#     AverageEnvironmentalImpact DECIMAL(5, 2),
#     KeyImpactAreas TEXT,
#     RecommendationsForImprovement TEXT,
#     FOREIGN KEY (ProductID) REFERENCES Products(ProductID)
# );
#
# ### **Displaying Created Tables**
#
# After executing the above SQL scripts, the following command was used to verify that all tables were successfully created:
#
# To show all tables in the currently selected database
# SHOW TABLES;
#
# ![][image1]
# ![][image2]
#
# ## **2\. Data Insertion & Sample Records**
#
# Once the tables were created, sample data was inserted to test the database functionality.
#
# ### **Sample Data Insertion \- Customers Table**
#
# INSERT INTO Customers (CustomerID, Name, Age, Region, PurchaseHistory, AverageSpending, PreferredCategory, LoyaltyScore) VALUES
# (1, 'Amit Sharma', 32, 'North', 'Laptop, Phone, Headphones', 25000.50, 'Electronics', 85),
# (2, 'Priya Verma', 27, 'West', 'Shoes, Handbag', 12000.75, 'Fashion', 70),
# (3, 'Rajesh Gupta', 40, 'East', 'Refrigerator, Washing Machine', 45000.00, 'Home Appliances', 90),
# (4, 'Neha Mehta', 29, 'South', 'Skincare, Perfume', 8000.30, 'Beauty', 60),
# (5, 'Vikram Singh', 35, 'North', 'LED TV, Home Theater', 50000.00, 'Electronics', 95),
# (6, 'Anjali Das', 31, 'West', 'Makeup Kit, Hair Dryer', 15000.20, 'Beauty', 78),
# (7, 'Suresh Reddy', 38, 'East', 'Treadmill, Dumbbells', 22000.00, 'Fitness', 85),
# (8, 'Kavita Iyer', 26, 'South', 'Sarees, Jewelry', 18000.60, 'Fashion', 75),
# (9, 'Manoj Nair', 45, 'North', 'Sofa Set, Dining Table', 70000.90, 'Home Decor', 98),
# (10, 'Sunita Pillai', 30, 'West', 'Books, Stationery', 6000.40, 'Books', 55),
# (11, 'Deepak Kumar', 34, 'East', 'Smartphone, Laptop', 40000.25, 'Electronics', 92),
# (12, 'Swati Bhatt', 28, 'South', 'Dress, Heels', 14000.80, 'Fashion', 68),
# (13, 'Arjun Malhotra', 41, 'North', 'Car Accessories, Helmets', 20000.50, 'Automobile', 88),
# (14, 'Reema Shah', 33, 'West', 'Organic Food, Supplements', 9500.90, 'Health', 72),
# (15, 'Rohan Deshmukh', 37, 'East', 'Shoes, Gym Equipment', 26000.60, 'Fitness', 80),
# (16, 'Meena Yadav', 25, 'South', 'Lipstick, Foundation', 8500.40, 'Beauty', 62),
# (17, 'Tarun Ghosh', 46, 'North', 'Luxury Watches, Sunglasses', 55000.00, 'Fashion', 94),
# (18, 'Pooja Saxena', 29, 'West', 'Curtains, Bedsheets', 11000.20, 'Home Decor', 70),
# (19, 'Ashok Patil', 36, 'East', 'Fan, Air Cooler', 18000.00, 'Home Appliances', 76),
# (20, 'Nidhi Agarwal', 31, 'South', 'Yoga Mat, Dumbbells', 9000.30, 'Fitness', 65),
# (21, 'Harish Menon', 43, 'North', 'Power Bank, Smart Watch', 22000.40, 'Electronics', 89),
# (22, 'Sonal Kapoor', 27, 'West', 'Bags, Earrings', 13000.00, 'Fashion', 74),
# (23, 'Gopal Srinivasan', 39, 'East', 'Grocery Items, Kitchen Tools', 10500.50, 'Groceries', 68),
# (24, 'Ritika Sinha', 28, 'South', 'Face Cream, Shampoo', 7500.60, 'Beauty', 58),
# (25, 'Sandeep Joshi', 42, 'North', 'Trekking Gear, Travel Accessories', 28000.20, 'Travel', 87),
# (26, 'Alok Mishra', 34, 'West', 'Guitar, Headphones', 15000.90, 'Music', 77),
# (27, 'Shruti Chatterjee', 30, 'East', 'Formal Shoes, Watches', 19000.00, 'Fashion', 79),
# (28, 'Parth Raj', 45, 'South', 'Smart TV, Gaming Console', 60000.00, 'Electronics', 99),
# (29, 'Vinay Thakur', 38, 'North', 'Coffee Machine, Blender', 20000.60, 'Home Appliances', 82),
# (30, 'Tanya Sehgal', 25, 'West', 'Hoodies, Sneakers', 12000.40, 'Fashion', 67),
# (31, 'Ravi Shetty', 37, 'East', 'Bicycles, Helmets', 25000.00, 'Fitness', 84),
# (32, 'Pallavi Kulkarni', 29, 'South', 'Makeup Brushes, Compact', 9500.30, 'Beauty', 66),
# (33, 'Sameer Khan', 44, 'North', 'Gold Jewelry, Luxury Bags', 85000.50, 'Luxury', 100),
# (34, 'Jyoti Bansal', 32, 'West', 'Office Chair, Desk', 19000.20, 'Home Decor', 71),
# (35, 'Aniket Banerjee', 41, 'East', 'Printers, Hard Drives', 29000.90, 'Electronics', 85),
# (36, 'Komal Joshi', 26, 'South', 'Nail Polish, Perfume', 7000.80, 'Beauty', 57),
# (37, 'Karan Arora', 39, 'North', 'Books, Kindle', 11000.40, 'Books', 63),
# (38, 'Rhea Das', 28, 'West', 'Body Wash, Essential Oils', 8000.30, 'Beauty', 60),
# (39, 'Abhinav Tyagi', 47, 'East', 'Car Tires, Car Perfume', 32000.50, 'Automobile', 90),
# (40, 'Smita Rao', 30, 'South', 'Dining Set, Wall Art', 17000.20, 'Home Decor', 73),
# (41, 'Mohit Chawla', 36, 'North', 'Gym Bag, Dumbbells', 15000.00, 'Fitness', 75),
# (42, 'Sneha Nair', 29, 'West', 'Handmade Crafts, Candles', 9500.70, 'Home Decor', 68),
# (43, 'Umesh Patil', 42, 'East', 'Tablet, Power Bank', 21000.30, 'Electronics', 86),
# (44, 'Simran Kapoor', 31, 'South', 'Designer Saree, Necklace', 25000.40, 'Fashion', 81),
# (45, 'Nitin Saxena', 35, 'North', 'Motorbike Gear, Gloves', 28000.00, 'Automobile', 88),
# (46, 'Payal Grover', 27, 'West', 'Sunscreen, Night Cream', 9000.50, 'Beauty', 61),
# (47, 'Ashish Mehta', 44, 'East', 'Action Figures, Toys', 13000.60, 'Toys', 69),
# (48, 'Ritika Arora', 33, 'South', 'Kurtis, Dupattas', 14000.90, 'Fashion', 72),
# (49, 'Yashwant Rao', 38, 'North', 'Camping Gear, Sleeping Bag', 30000.50, 'Travel', 89),
# (50, 'Preeti Sinha', 29, 'West', 'Earrings, Makeup Kit', 11000.30, 'Beauty', 64);
#
# \-- Show all data from the Customers table SELECT \* FROM Customers;
# ![][image3]
# ![][image4]
# ![][image5]
#
# INSERT INTO Products (Name, Category, ReturnRate, DisposalRate, Price, Supplier, SustainabilityScore) VALUES
# ('Amul Butter', 'Dairy', 2.50, 1.20, 50.00, 'Amul India Pvt Ltd', 8.5),
# ('Tata Salt', 'Groceries', 1.80, 0.90, 25.00, 'Tata Consumer Products', 9.0),
# ('Parle-G Biscuits', 'Snacks', 3.20, 2.00, 10.00, 'Parle Products Ltd', 8.0),
# ('Brooke Bond Red Label Tea', 'Beverages', 2.00, 1.50, 150.00, 'Hindustan Unilever Ltd', 7.5),
# ('Dabur Honey', 'Health', 1.50, 1.00, 250.00, 'Dabur India Ltd', 9.2),
# ('Patanjali Aloe Vera Gel', 'Personal Care', 4.50, 3.00, 80.00, 'Patanjali Ayurveda', 8.8),
# ('Godrej No.1 Soap', 'Personal Care', 2.80, 1.50, 35.00, 'Godrej Consumer Products', 8.3),
# ('Boroline Antiseptic Cream', 'Healthcare', 1.70, 1.00, 40.00, 'GD Pharmaceuticals', 9.5),
# ('Haldiram’s Kaju Katli', 'Sweets', 5.00, 3.00, 550.00, 'Haldiram Snacks Pvt Ltd', 7.0),
# ('Himalaya Neem Face Wash', 'Beauty', 3.50, 2.20, 120.00, 'Himalaya Herbals', 8.7),
# ('Fevicol Adhesive', 'Stationery', 1.20, 0.80, 50.00, 'Pidilite Industries', 9.3),
# ('Asian Paints Royale', 'Home Decor', 1.00, 0.50, 900.00, 'Asian Paints Ltd', 9.8),
# ('Lakme Kajal', 'Beauty', 3.80, 2.50, 180.00, 'Hindustan Unilever Ltd', 8.4),
# ('Raymond Suit Fabric', 'Clothing', 0.90, 0.40, 2500.00, 'Raymond Ltd', 9.7),
# ('Bajaj LED Bulb', 'Electronics', 1.50, 0.80, 220.00, 'Bajaj Electricals', 9.1),
# ('Hero Splendor Bike', 'Automobile', 0.50, 0.20, 70000.00, 'Hero MotoCorp', 9.0),
# ('Royal Enfield Classic 350', 'Automobile', 0.30, 0.10, 195000.00, 'Royal Enfield India', 9.5),
# ('Samsung Galaxy M14', 'Electronics', 5.50, 4.00, 18000.00, 'Samsung India', 8.0),
# ('Maruti Swift Car', 'Automobile', 0.40, 0.20, 800000.00, 'Maruti Suzuki India', 9.6),
# ('Bose SoundLink Speaker', 'Electronics', 0.90, 0.40, 12000.00, 'Bose Corporation India', 9.4),
# ('Titan Raga Watch', 'Accessories', 1.10, 0.70, 5500.00, 'Titan Company Ltd', 9.2),
# ('Linc Gel Pen', 'Stationery', 3.00, 1.80, 20.00, 'Linc Pens Ltd', 8.1),
# ('Santoor Sandalwood Soap', 'Personal Care', 2.30, 1.50, 40.00, 'Wipro Consumer Care', 8.6),
# ('Britannia Cheese Slices', 'Dairy', 2.20, 1.00, 110.00, 'Britannia Industries', 8.9);
#
# \-- Show all data from the Products table SELECT \* FROM Products;
# ![][image6]
#
# ![][image7]
#
# INSERT INTO Orders (CustomerID, ProductID, Quantity, OrderDate, TotalPrice, PaymentMethod, OrderStatus)
# VALUES (1, 3, 1, '2024-02-01', 124999.00, 'Credit Card', 'Delivered');
# INSERT INTO Orders (CustomerID, ProductID, Quantity, OrderDate, TotalPrice, PaymentMethod, OrderStatus) VALUES
# (1, 3, 1, '2024-02-01', 124999.00, 'Credit Card', 'Delivered'),
# (2, 7, 2, '2024-02-02', 29998.00, 'Debit Card', 'Delivered'),
# (3, 15, 1, '2024-02-03', 59999.00, 'UPI', 'Shipped'),
# (4, 20, 3, '2024-02-04', 897.00, 'Net Banking', 'Pending');
# INSERT INTO Orders (CustomerID, ProductID, Quantity, OrderDate, TotalPrice, PaymentMethod, OrderStatus) VALUES
# (5, 1, 1, '2024-02-05', 79999.00, 'Credit Card', 'Delivered'),
# (6, 10, 1, '2024-02-06', 12999.00, 'Debit Card', 'Cancelled'),
# (7, 5, 1, '2024-02-07', 44999.00, 'Cash on Delivery', 'Shipped'),
# (8, 12, 2, '2024-02-08', 39998.00, 'Credit Card', 'Delivered');
#
# INSERT INTO Orders (CustomerID, ProductID, Quantity, OrderDate, TotalPrice, PaymentMethod, OrderStatus) VALUES
# (11, 6, 2, '2024-02-11', 25998.00, 'Debit Card', 'Delivered'),
# (12, 14, 1, '2024-02-12', 7999.00, 'UPI', 'Shipped'),
# (13, 21, 1, '2024-02-13', 13999.00, 'Credit Card', 'Pending'),
# (14, 19, 3, '2024-02-14', 897.00, 'Net Banking', 'Delivered'),
# (15, 8, 1, '2024-02-15', 4999.00, 'Cash on Delivery', 'Delivered'),
# (16, 22, 1, '2024-02-16', 6999.00, 'Debit Card', 'Shipped'),
# (17, 11, 1, '2024-02-17', 22999.00, 'Credit Card', 'Delivered'),
# (18, 2, 1, '2024-02-18', 69999.00, 'Credit Card', 'Delivered'),
# (19, 9, 2, '2024-02-19', 17998.00, 'UPI', 'Pending'),
# (20, 16, 3, '2024-02-20', 2397.00, 'Cash on Delivery', 'Delivered');
# INSERT INTO Orders (CustomerID, ProductID, Quantity, OrderDate, TotalPrice, PaymentMethod, OrderStatus) VALUES
# (21, 4, 1, '2024-02-21', 29999.00, 'Credit Card', 'Cancelled'),
# (22, 13, 2, '2024-02-22', 65998.00, 'Debit Card', 'Delivered'),
# (23, 24, 1, '2024-02-23', 499.00, 'UPI', 'Shipped'),
# (24, 23, 1, '2024-02-24', 499.00, 'Credit Card', 'Delivered'),
# (25, 17, 1, '2024-02-25', 3999.00, 'Cash on Delivery', 'Pending'),
# (26, 2, 1, '2024-02-26', 69999.00, 'Credit Card', 'Shipped'),
# (27, 10, 2, '2024-02-27', 25998.00, 'Debit Card', 'Delivered'),
# (28, 5, 1, '2024-02-28', 44999.00, 'Net Banking', 'Delivered'),
# (29, 15, 1, '2024-02-29', 59999.00, 'UPI', 'Cancelled'),
# (30, 7, 2, '2024-03-01', 29998.00, 'Credit Card', 'Delivered');
#
# INSERT INTO Orders (CustomerID, ProductID, Quantity, OrderDate, TotalPrice, PaymentMethod, OrderStatus) VALUES
# (41, 1, 1, '2024-03-12', 79999.00, 'Credit Card', 'Shipped'),
# (42, 23, 1, '2024-03-13', 499.00, 'UPI', 'Cancelled'),
# (43, 16, 2, '2024-03-14', 1598.00, 'Net Banking', 'Delivered'),
# (44, 18, 3, '2024-03-15', 17997.00, 'Debit Card', 'Delivered'),
# (45, 4, 1, '2024-03-16', 29999.00, 'Credit Card', 'Shipped'),
# (46, 13, 1, '2024-03-17', 32999.00, 'UPI', 'Delivered'),
# (47, 7, 1, '2024-03-18', 14999.00, 'Cash on Delivery', 'Delivered'),
# (48, 3, 2, '2024-03-19', 249998.00, 'Credit Card', 'Pending'),
# (49, 22, 1, '2024-03-20', 6999.00, 'Debit Card', 'Delivered'),
# (50, 9, 1, '2024-03-21', 8999.00, 'Credit Card', 'Delivered');
# \- Show all data from the Orders table SELECT \* FROM Orders;
# ![][image8]
# ![][image9]
#
# ![][image10]
#
# INSERT INTO WasteMetrics (ProductID, ReturnReason, EnvironmentalImpact, CarbonFootprint, RecyclabilityScore) VALUES
# (1, 'Damaged on Arrival', 'High plastic waste due to packaging', 12.5, 7.8),
# (2, 'Defective Product', 'Electronic waste concerns', 18.2, 5.6),
# (3, 'Wrong Item Delivered', 'Excess transportation emissions', 10.3, 8.2),
# (4, 'Customer Changed Mind', 'Unnecessary resource utilization', 5.6, 9.1),
# (5, 'Expired Product', 'Food waste and methane emissions', 20.8, 6.5),
# (6, 'Size Mismatch', 'High return rate increases emissions', 8.4, 7.2),
# (7, 'Better Price Found Elsewhere', 'Returns increase logistics emissions', 6.7, 9.0),
# (8, 'Quality Not as Expected', 'Materials not fully recyclable', 13.1, 6.2),
# (9, 'Incomplete Product', 'Extra production needed for replacements', 15.5, 7.3),
# (10, 'Packaging Issues', 'Non-biodegradable packaging waste', 9.8, 8.5);
#
# \-- Show all data from the WasteMetrics table SELECT \* FROM WasteMetrics;
#
# ![][image11]
#
# ![][image12]
#
# INSERT INTO EnvironmentalImpactSummary (ProductID, AverageEnvironmentalImpact, KeyImpactAreas, RecommendationsForImprovement) VALUES
# (1, 8.2, 'Plastic waste, transportation emissions', 'Reduce packaging waste, use biodegradable materials'),
# (2, 7.5, 'Electronic waste, toxic chemicals', 'Implement e-waste recycling program, improve durability'),
# (3, 6.8, 'Transportation, fuel emissions', 'Optimize delivery routes, use electric vehicles'),
# (4, 5.3, 'Resource wastage from returns', 'Improve product descriptions to reduce returns'),
# (5, 9.1, 'Food waste, methane emissions', 'Enhance storage conditions, introduce composting initiatives'),
# (6, 7.0, 'High return rate, emissions', 'Provide better size guides, AR-based fitting solutions'),
# (7, 6.5, 'Logistics emissions', 'Encourage local sourcing, reduce return incentives'),
# (8, 8.0, 'Material non-recyclability', 'Switch to sustainable materials, improve production methods'),
# (9, 7.4, 'Extra production waste', 'Improve quality control, minimize defective rates'),
# (10, 8.9, 'Non-biodegradable packaging', 'Use recycled packaging, offer returnable packaging options');
#
# \-- Show all data from the EnvironmentalImpactSummary table SELECT \* FROM EnvironmentalImpactSummary;
#
# ![][image13]
#
# ![][image14]
#
# INSERT INTO Suppliers (Name, ContactInfo, Region, ProductSupplied, SupplierRating) VALUES
# ('GreenTech Supplies', 'contact@greentech.com', 'North America', 'Solar Panels', 4.5),
# ('EcoPlast Industries', 'support@ecoplast.com', 'Europe', 'Biodegradable Packaging', 4.2),
# ('Sustainable Metals Ltd.', 'info@susmetals.com', 'Asia', 'Recycled Aluminum', 4.7),
# ('Organic Textiles Co.', 'hello@organictextiles.com', 'South America', 'Organic Cotton Fabrics', 4.1),
# ('Renewable Woodworks', 'contact@renewablewood.com', 'North America', 'Sustainable Timber', 4.6),
# ('E-Waste Solutions', 'support@ewastesolutions.com', 'Europe', 'Recycled Electronic Components', 3.9),
# ('BioAgro Corp.', 'info@bioagro.com', 'Africa', 'Compostable Agricultural Products', 4.3),
# ('EcoLighting Ltd.', 'hello@ecolighting.com', 'Asia', 'Energy-Efficient LED Bulbs', 4.8),
# ('Pure Water Systems', 'support@purewatersys.com', 'Australia', 'Water Filtration Systems', 4.0),
# ('ZeroWaste Packaging', 'contact@zerowastepack.com', 'North America', 'Recyclable Packaging Materials', 4.5),
# ('GreenSteel Inc.', 'info@greensteel.com', 'Europe', 'Low-Carbon Steel', 4.4),
# ('EcoChemicals Ltd.', 'support@ecochemicals.com', 'South America', 'Non-Toxic Cleaning Agents', 3.8),
# ('Solar Innovators', 'hello@solarinnovators.com', 'Asia', 'Solar Battery Storage', 4.6),
# ('Green Logistics Co.', 'contact@greenlogistics.com', 'Africa', 'Eco-Friendly Transport Services', 4.2),
# ('Sustainable Plastics', 'support@susplastics.com', 'Australia', 'Recycled Plastic Components', 3.9),
# ('Green Energy Solutions', 'info@greenenergy.com', 'North America', 'Wind Turbines', 4.7),
# ('EcoPackaging Corp.', 'hello@ecopackaging.com', 'Europe', 'Compostable Food Containers', 4.3);
#
# \-- Show all data from the Suppliers table SELECT \* FROM Suppliers;
#
# ![][image15]
# ![][image16]
#
# INSERT INTO Recommendations (CustomerID, ProductID, SuggestedAction, ActionImpact, ActionDate) VALUES
# (1, 3, 'Offer discounts for bulk purchases', 'Increases sales and reduces packaging waste', '2025-02-01'),
# (2, 5, 'Improve product descriptions', 'Reduces return rates and customer dissatisfaction', '2025-02-02'),
# (3, 8, 'Introduce a loyalty program', 'Enhances customer retention and engagement', '2025-02-03'),
# (4, 2, 'Switch to biodegradable packaging', 'Minimizes environmental impact', '2025-02-04'),
# (5, 7, 'Optimize delivery logistics', 'Reduces carbon footprint from transportation', '2025-02-05'),
# (6, 10, 'Use AI-powered recommendations', 'Improves personalized marketing and sales', '2025-02-06'),
# (7, 4, 'Partner with eco-friendly suppliers', 'Strengthens sustainability efforts', '2025-02-07'),
# (8, 6, 'Provide detailed size guides', 'Reduces return rates due to sizing issues', '2025-02-08'),
# (9, 1, 'Implement a trade-in program', 'Encourages recycling and reusability', '2025-02-09'),
# (10, 9, 'Introduce AR-based try-on features', 'Enhances customer experience and reduces returns', '2025-02-10');
#
# \-- Show all data from the Recommendations table SELECT \* FROM Recommendations;
#
# ![][image17]
#
# ![][image18]
#
# INSERT INTO Inventory (ProductID, StockLevel, ReorderThreshold, StorageLocation, RestockDate, SupplierID) VALUES
# (1, 150, 50, 'Warehouse A \- Shelf 3', '2025-02-20', 3),
# (2, 80, 30, 'Warehouse B \- Section 2', '2025-02-18', 5),
# (3, 200, 60, 'Warehouse C \- Rack 1', '2025-02-22', 8),
# (4, 50, 20, 'Warehouse A \- Shelf 5', '2025-02-15', 2),
# (5, 120, 40, 'Warehouse D \- Bay 4', '2025-02-25', 6),
# (6, 30, 15, 'Warehouse B \- Section 6', '2025-02-12', 10),
# (7, 90, 35, 'Warehouse E \- Zone 3', '2025-02-19', 4),
# (8, 175, 55, 'Warehouse F \- Shelf 7', '2025-02-24', 7),
# (9, 60, 25, 'Warehouse C \- Rack 2', '2025-02-16', 12),
# (10, 110, 45, 'Warehouse A \- Shelf 8', '2025-02-28', 9),
# (11, 200, 75, 'Warehouse D \- Bay 1', '2025-02-22', 15),
# (12, 140, 50, 'Warehouse G \- Zone 2', '2025-02-21', 14),
# (13, 95, 30, 'Warehouse H \- Section 4', '2025-02-17', 11),
# (14, 180, 65, 'Warehouse B \- Section 5', '2025-02-23', 13),
# (15, 75, 30, 'Warehouse F \- Shelf 9', '2025-02-20', 1);
#
# \-- Show all data from the Inventory table SELECT \* FROM Inventory;
#
# ![][image19]
# ![][image20]
#
# ## **3\. Query Execution & Outputs**
#
# ### **1\) Fetching Age-Wise Product Preference Analysis**
#
# **Identifying which age group prefers which product category the most.**
#
# ***![][image21]***
#
# **![][image22]**
# **![][image23]**
#
# **Business Insight:** Helps in personalized marketing by targeting customers based on age preferences.
#
# ## **2\) High Return Rate Products**
#
# **Find products that are being returned frequently, indicating quality issues.**
#
# ***![][image24]***
#
# **![][image25]**
# **Business Insight:** Companies can identify problematic products and take corrective actions (e.g., better quality control or supplier changes).
#
# ## **3\) Loyal High-Spending Customers**
#
# **Find the top 10 customers who frequently shop and spend the most.**
#
# ***![][image26]***
#
# ***![][image27]***
#
# **Business Insight:** These customers can be offered loyalty programs or exclusive discounts to maintain long-term relationships.
#
# ## **4\) Regional Purchase Patterns**
#
# **Analyze which regions are ordering which product categories the most.**
#
# ***![][image28]***
#
# ***![][image29]***
#
# ***![][image30]***
#
# **Business Insight:** Helps in regional inventory management and localized advertising campaigns.
#
# ## **5️) Best Performing Sustainable Products**
#
# **Identify top eco-friendly products based on sustainability score.**
#
# ***![][image31]***
#
# **![][image32]**
#  **Business Insight:** Helps promote eco-friendly products and attract customers who care about sustainability.
#
# ## **6️) Supplier Performance Analysis**
#
# **Check which suppliers have the most late deliveries.**
#
# ***![][image33]***
#
# ***![][image34]***
#
#  **Business Insight:** Helps businesses negotiate better terms with unreliable suppliers or find alternative vendors.
#
#  **Interpretation (Even if Empty)**
#
# * Empty result means suppliers are reliable and delivering on time—a positive business insight.
# * If results appear, it highlights underperforming suppliers who might impact operations.
#
# ## **4️) Process Optimization & Automation**
#
# **Find the average delay time for pending orders.**
#
# ***![][image35]***
#
# ***![][image36]***
#
# **Business Impact:**
#
# * Identify how long orders remain pending, affecting delivery timelines.
# * Set better automation rules for order follow-ups and escalation.
# * Process Optimization → Track average delay times to improve workflows and automation.
# * Helps determine how long orders are being delayed on average.
# * Optimize order fulfillment timelines to improve efficiency.
#
# ## **5\) Supplier Performance & Reliability**
#
# **Find suppliers with the most pending orders.**
#
# ***![][image37]***
#
# ***![][image38]***
#
# **Business Impact:**
#
# * Identify which suppliers are unreliable due to frequent pending orders.
# * Plan alternate sourcing strategies if certain suppliers consistently fail.
#
# * ### Business Insights
#
# *  Helps identify suppliers responsible for order delays
#   Supports supplier performance evaluation
#    Assists in negotiating better terms with high-delay suppliers
#
#
# ### **6\) Inventory & Demand Forecasting**
#
# **Find the most pending products to understand demand vs. supply gaps.**
#
# ***![][image39]***
#
# ***![][image40]***
#
# **Business Impact:**
#
# * Identify high-demand products that frequently go out of stock.
# * Optimize inventory management to avoid stock shortages.
#
# ### **Business Insights:**
#
# * Identifies high-demand products that may be facing supply chain issues
#   Helps in inventory management by highlighting stock shortages or delays
#   Supports supply chain optimization by tracking which products need urgent restocking.
#
#
#
#
# ### **7\) Customer Satisfaction & Revenue Loss**
#
# **Find the total value of pending orders per supplier.**
#
# ***![][image41]***
#
# **Business Impact:**
#
# * Understand the financial impact of pending orders.
# * Identify which suppliers are delaying high-value orders, affecting revenue.
#
# ### **Business Insights:**
#
# * Identifies suppliers with the most financial impact due to delayed orders
# * Helps in prioritizing supplier management efforts for high-value pending orders
# * Supports decision-making for renegotiating contracts or diversifying supplier sources
#
# **Additional Query for Delayed Orders Analysis**
#
# **Find the average delay time for pending orders.**
#
# ***![][image42]***
#
# **Business Impact:**
#
# * Helps determine how long orders are being delayed on average.
# * Optimize order fulfillment timelines to improve efficiency.
#
# ## **8\) Predictive Restocking Analysis**
#
# **Find products that will run out of stock soon based on past sales data.**
#
# **Business Insight:** Helps in better inventory planning and avoiding stockouts.
#
# **![][image43]**
#
# ***![][image44]***
#
# #### **Predictive Restocking Analysis (Stockout Prediction)**
#
# **Find products at risk of stockout based on recent sales trends.**
#
# **Business Insight:**
#
# * Identifies products that might go out of stock soon.
# * Helps in restocking decisions to prevent lost sales.
#
# ## **9\) Monthly Revenue Trends**
#
# ***Analyze revenue trends over time.***
#
# ***![][image45]***
#
# ***![][image46]***
#
# **Business Insight: Helps in revenue forecasting and identifying seasonal trends.**
#
# ## **10\) High Demand, Low Supply Products**
#
# **Find products that are selling fast but have low stock remaining.**
#
# ***![][image47]***
#
# ***![][image48]***
#
# **Business Insight:** Helps in priority restocking to prevent lost sales**.**
#
# **Interpretation (Even if Empty)**
#
# * If no products meet this condition, it’s good news—stock levels are being managed well.
# * If results exist, it shows which products need urgent restocking.
#
# ## **11\) Customers with Frequent Returns**
#
# **Find customers who return products frequently.**
#
# ***![][image49]***
#
# ***![][image50]***
#
# **Business Insight:** Helps in identifying customers with habitual returns, which may indicate fraud or dissatisfaction.
#
# **– Query For Fraud Detection**
#
# **(1️)Detect Customers Placing Multiple High-Value Orders in a Short Time**
#
# ***![][image51]***
#
# ***![][image52]***
#
# ### **Business Insights**
#
# * Detects potential fraudulent activity by identifying customers making abnormally frequent high-value purchases
# * Prevents financial losses by flagging suspicious bulk transactions for review
# * Supports fraud prevention teams in setting better transaction monitoring rules
# * Helps in customer segmentation, distinguishing between bulk buyers and potential fraud cases
#
# **(2) Detect Customers with Frequent Order Cancellations or Refunds**
#
# **![][image53]**
#
# ***![][image54]***
#
# ###  **Business Insights**
#
# Helps detect refund abuse and prevents potential financial losses.
# Identifies problematic customers who frequently cancel orders.
# Supports the fraud prevention team by flagging suspicious activities for further review.
#
# **(3) Detect Customers Using Multiple Payment Methods in a Short Time**
#
# ***![][image55]***
#
# ***![][image56]***
#
# ### **Business Insights**
#
# Fraudsters often test multiple payment methods before making fraudulent purchases.
# Helps detect stolen credit card usage or account takeover fraud.
# Can also highlight customers with legitimate bulk purchases, helping in segmentation.
#
# **(4) Detect Customers Placing Orders in Multiple Regions**
#
# ***![][image57]***
#
# ***![][image58]***
#
# ### **Business Insights**
#
# * Detects potential account sharing or fraudulent activity where a single account is used in different regions.
# * Identifies unusual purchasing behavior, which could be a sign of an account takeover (ATO) fraud.
# * Supports delivery optimization by checking if customers are ordering across unrealistic distances.
# * Helps identify fake accounts, which can be used for fraud or reward manipulation.
#
# **→ no customers are placing orders in multiple regions,**
#
# **(5) Detect Customers with Unusual Spending vs. Loyalty Score**
#
# **With Threshold Condition : (TotalSpent \> 50000 AND LoyaltyScore \< 50\)**
#
# ***![][image59]***
#
# ***![][image60]***
#
# **With Threshold Condition :**
#
# **HAVING (TotalSpent \> 20000 AND LoyaltyScore \< 60\)**
#
# **OR (TotalSpent \< 10000 AND LoyaltyScore \> 70\)**
#
# ***![][image61]***
#
# ***![][image62]***
#
# ###  **Business Insights**
#
# * Identifies customers whose spending does not align with their loyalty score, indicating possible fraud or rewards manipulation.
# * Flags high-spending, low-loyalty customers, who could be using stolen payment methods or engaging in suspicious behavior.
# * Detects loyalty abuse, where customers with low spending but high loyalty scores may be gaming the system.
# * Helps in fraud prevention by ensuring loyalty programs are used by genuine customers.
#
# ***(6)*** **Detect Customers Changing Their Preferred Category Frequently**
#
# ***![][image63]***
#
# ***![][image64]***
#
# ### **Business Insights**
#
# * Helps detect resellers or fraudulent accounts that are buying across multiple categories abnormally.
# * Flags customers whose purchase history does not align with their stated preferences, signaling possible misuse of the platform.
# * Supports customer segmentation efforts, allowing businesses to fine-tune marketing strategies.
# * Can help identify suspicious patterns in bulk buying across different product types, preventing supply chain manipulation.
#
# ## **Stress Testing the Database**
#
# ### **1\) Measuring Query Performance Using EXPLAIN**
#
# This helps analyze how the SQL engine processes queries, identifying bottlenecks and ensuring indexes are utilized efficiently.
#
# #### **Analysis of Query Execution Using EXPLAIN**
#
# **Objective:**
# To assess how efficiently the SQL query executes and identify potential performance bottlenecks.
#
# **What Was Done?**
# We executed the `EXPLAIN` command on a query that sorts data by the `TotalSpent` column in descending order (DESC). This command provides details on how the database processes the query, including execution steps and estimated performance impact.
#
# #### **Query Execution Plan Analysis**
#
# ![][image65]
#
# ![][image66]
#
# **Understanding the Output:**
#
# * The output shows that the query involves a sorting operation on `TotalSpent` in descending order.
# * The execution plan reveals whether indexes are used or if the database is performing a full table scan.
# * If sorting is done without an index, the database might scan the entire dataset, which can slow down performance.
#
# **Key Takeaways & Next Steps:**
# If the query is slow, we should:
#
# * Ensure that the `TotalSpent` column has an index to speed up sorting.
# * Consider using indexed views or pre-sorted tables if sorting is frequently needed.
# * Optimize the query structure to avoid unnecessary computations.
#
# **By making these improvements, we can reduce query execution time and enhance overall database performance.**
#
# ### **2\) Running Queries Repeatedly & Monitoring Performance**
#
# * This step ensures database stability under load and identifies inefficient queries.
# * This helps track database load and performance over time.
# * Checking session status to detect slow queries, temporary tables, and inefficient scans.
#
# #### **Performance Monitoring Queries**
#
# ![][image67]
#
# SHOW SESSION STATUS LIKE 'Created\_tmp\_tables'; \-- Shows temporary tables created, which impact performance.
#
# ![][image68]
#
# ### **2.1 Analyzing Table Scans for Query Optimization**
#
# #### **Objective:**
#
# To monitor **full table scans** that may lead to **performance inefficiencies** in query execution.
#
# #### **What Was Done?**
#
# We executed the following SQL command:
#
# SHOW SESSION STATUS LIKE 'Handler\_read\_rnd\_next';
#
# ![][image69]
#
# This command helps track table scans by measuring the number of times rows are read sequentially when no index is used.
#
# #### **Understanding the Output:**
#
# * The result shows 8,332 sequential row reads, which indicates that queries are not using indexes effectively and are scanning large portions of tables.
# * A high value suggests that the database is performing full table scans instead of using indexed lookups, leading to longer execution times and increased resource consumption.
#
# #### **Key Takeaways & Next Steps:**
#
# * Check if indexes exist on the queried columns and ensure they are being utilized properly.
# * Optimize queries to use indexed searches rather than full table scans.
# * Rewrite queries to limit the number of scanned rows (e.g., using `WHERE` conditions efficiently).
# * If full table scans are necessary (e.g., due to reporting queries), consider partitioning large tables for better performance.
#
# By reducing the Handler\_read\_rnd\_next count, queries can run faster and improve overall database efficiency.
#
# ### **2.2 Analysis of Slow Queries Monitoring**
#
#  **Objective:**
#
# To track **slow-running queries** that may impact **database performance** and require optimization.
#
# #### **What Was Done?**
#
# We executed the following SQL command:
#
# SHOW STATUS LIKE 'Slow\_queries';
#
# ![][image70]
#
# Action: If too many slow queries are detected, indexing or query restructuring may be needed.
#
# This command provides the **number of queries** that took **longer than the configured threshold** (typically **10 seconds** by default) to execute.
#
# #### **Understanding the Output:**
#
# * The result shows **0 slow queries**, meaning **all queries executed efficiently** within the acceptable time frame.
# * A value **greater than 0** would indicate that some queries are taking longer than expected, requiring **further optimization**.
#
# #### **Key Takeaways & Next Steps:**
#
# * **Since no slow queries are detected, no immediate action is required.**
#
# * If slow queries appear in the future:
#
# - **Enable the slow query log** to track problematic queries:
#   `SET GLOBAL slow_query_log = 1;`
# - **Analyze queries** using `EXPLAIN` to check execution plans.
# - **Optimize indexing** to ensure efficient lookups.
# - **Consider query restructuring** to improve performance.
#
# This check confirms that the current **query execution time is optimal**, contributing to **smooth database performance**.
#
# ## **3 Checking for Edge Cases (Handling Empty Tables and Extreme Values)**
#
# Ensuring database queries handle both **empty datasets** and **extreme values** is crucial for robustness. This test verifies that queries **do not fail** when no records exist and ensures they **process unusually high values correctly**.
#
# ### **Step 1: Handling Empty Tables**
#
# #### **Objective:**
#
# * Ensure that queries **execute without errors** even if the table contains no data.
# * Validate that database operations handle missing records gracefully.
#
# #### **Actions Taken:**
#
# 1. **Deleted all records from the Orders table** to simulate an empty dataset.
# 2. **Checked if SELECT queries still executed correctly** without failure.
#
# #### **SQL Commands Executed:**
#
# ![][image71]
#
# #### **Observations & Results:**
#
# * The `DELETE` operation successfully cleared all records.
# * The `SELECT` query executed without errors, returning an empty result set.
# * No system crashes or unexpected failures occurred.
#
# **Conclusion:** The database handles empty tables correctly, ensuring stability even when no records exist.
#
# ### **Step 2: Handling Extreme Values**
#
# #### **Objective:**
#
# * Test if the database **correctly processes high numerical values** without truncation or failure.
# * Ensure SQL queries return **expected results** when filtering extreme data points.
#
# #### **Actions Taken:**
#
# 1. **Inserted an order with abnormally high values** (e.g., Quantity \= `9999`, TotalPrice \= `999999.99`).
# 2. **Queried the database** to confirm whether these values were stored and retrieved correctly.
#
# #### **SQL Commands Executed:**
#
# ![][image72]
#
# #### **Inserted Values:**
#
# * **Quantity:** 9999 (Unusually high for a single order)
# * **TotalPrice:** 999999.99 (Extreme monetary value)
#
# #### **Observations & Results:**
#
# The insertion of extreme values **succeeded without truncation or error**.
# The `SELECT` query accurately retrieved the inserted record.
# No database crashes or performance slowdowns occurred.
#
# **Potential Risks Identified:**
#
# * Extremely high `Quantity` values may indicate **potential data entry errors** or fraudulent transactions.
# * The system should be tested for **performance issues** when handling large numerical values.
#
# **Output:**
#
# ![][image73]
#
# **Conclusion:** The database correctly handles extreme values, but **data validation rules** may be needed to prevent unrealistic entries (e.g., setting upper limits on Quantity or Price).
#
# ### **Final Takeaways & Recommendations:**
#
# * Queries executed **successfully on empty tables**, confirming robustness.
# * Extreme values were **stored and retrieved correctly**, ensuring database integrity.
# * **Future Improvements:** Implement **validation constraints** (e.g., MAX values for `Quantity`, `Price`) to prevent unrealistic inputs.
#
# **4\.   Simulate Concurrent Users**
#
# ### **→ Analysis of Database Locking Issues and Performance Impacts**
#
# #### **Objective of the Analysis**
#
# The purpose of this analysis was to evaluate how the database handles multiple users accessing it simultaneously. To achieve this, we ran a system command (`SHOW ENGINE INNODB STATUS;`) that provides detailed insights into how transactions interact with the database and whether any issues, such as locking or deadlocks, are occurring.
#
# This helps detect performance drops when multiple users query the database simultaneously. SHOW ENGINE INNODB STATUS;
#
# Checks for transaction locks, row locks, and deadlocks.
#
# #### **SQL Commands Executed:**
#
# ![][image74]
#
# **Output:**
#
# ![][image75]
#
# #### **Key Findings from the Analysis**
#
# * **Identification of Locking Issues**
#   * When multiple users access the database at the same time, conflicts can arise where one process **locks** a row of data, preventing others from accessing it.
#   * If too many locks occur, it can slow down operations, leading to **delays in data retrieval and processing**.
#   * In extreme cases, **deadlocks** occur, meaning two processes are waiting for each other to release resources, causing a system freeze or failure.
# * **Impact on Performance**
#   * This test simulates a real-world scenario where employees or customers query the database at the same time.
#   * If the system struggles to handle these simultaneous requests efficiently, it can result in **slower response times, delayed transactions, and potential system downtime**.
#   * Our findings indicate whether these issues are present and, if so, how severe they are.
#
# #### **Business Implications**
#
# * **Operational Efficiency**: If locking issues are frequent, employees may experience slow system performance, affecting productivity.
# * **Customer Experience**: A database struggling with deadlocks can lead to **delayed transactions**, negatively impacting customer service.
# * **Scalability Concerns**: As the organization grows, these bottlenecks could **intensify**, requiring proactive solutions.
#
# #### **Recommendations for Improvement**
#
# * **Monitor and Optimize Database Queries**: Ensure that data retrieval processes are optimized to reduce unnecessary locks.
# * **Improve Transaction Handling**: Adjust how the system processes multiple user requests to minimize conflicts.
# * **Increase System Resources if Necessary**: If performance issues persist, upgrading database infrastructure may be required.
#
# By proactively addressing these challenges, we can enhance system performance, ensuring seamless operations even during peak usage times.
#
# ### **Analysis of `SHOW PROCESSLIST;`**
#
# The `SHOW PROCESSLIST;` command was executed to analyze the currently running queries and database processes. This helps in identifying any performance bottlenecks, long-running queries, and idle connections that may impact system efficiency.
#
# #### **SQL Commands Executed:** SHOW PROCESSLIST;
#
# ### **Output for Show Processlist:**
#
# Displays currently running queries and their states.
#
# ![][image76]
#
#  Action: \-- If too many locks or waiting queries appear, investigate and optimize table indexes or use connection pooling.
#
# From the results:
#
# 1. **Event Scheduler Process Running for an Extended Period:**
#    * The process with `Id = 5` is an **event scheduler** running for 186710 seconds.
#    * This indicates that a scheduled task has been active for a prolonged duration.
#    * **Managerial Implication:** If not monitored, long-running processes may consume resources unnecessarily. A review of scheduled jobs is required to determine if adjustments or termination are needed.
# 2. **Idle Database Connection (Sleep State):**
#    * The process with `Id = 14` (connected to `librarydb`) has been in a **sleep state** for 18 seconds.
#    * This suggests that a session was opened but is currently inactive.
#    * **Managerial Implication:** Multiple idle connections can slow down the database. It is recommended to **set a timeout for inactive connections** to free up resources efficiently.
# 3. **Active Query in Initialization Stage:**
#    * The process with `Id = 15` (executing a query on `consumerwasteanalytics` database) is in the **"init"** state.
#    * This means the query has started but has not yet executed fully. If it remains in this state for too long, it may indicate **performance issues such as table locks, inefficient indexing, or resource contention**.
#    * **Managerial Implication:** Queries stuck in the initialization stage may lead to slower database performance. Further investigation is needed to optimize the query execution.
#
# ### **Recommendations and Next Steps:**
#
# * **Monitor long-running scheduled jobs** and terminate unnecessary ones.
# * **Implement automatic disconnection policies** for inactive database connections to improve efficiency.
# * **Analyze query execution plans** for slow queries and optimize indexes if necessary.
# * **Use `SHOW FULL PROCESSLIST;`** for a more detailed breakdown of query execution states.
#
# By taking these actions, database performance can be enhanced, reducing system slowdowns and improving overall efficiency.
#
# # **NORMALIZATION**
#
# ### Normalization is the process of organizing a database to:
#
# * ### **Eliminate redundancy**
#
# * ### **Ensure data integrity**
#
# * ### **Optimize query performance**
#
# ### It involves breaking data into multiple related tables while maintaining consistency. The key steps are:
#
# 1. ### **First Normal Form (1NF)** – Ensures atomicity (each column contains only one value) and that there are no repeating groups.
#
# 2. ### **Second Normal Form (2NF)** – Ensures full functional dependency (no partial dependencies).
#
# 3. ### **Third Normal Form (3NF)** – Eliminates transitive dependencies.
#
# ### We have checked for 1NF compliance first.
#
# ### **Applying First Normal Form (1NF)**
#
# Rule: 1NF requires that:
#
# * Each column contains atomic (indivisible) values.
# * Each row is unique, with a primary key.
# * No repeating groups or arrays in a single column.
#
# ### **Checking if the Data is Already in 1NF**
#
# To verify if the data is in **1NF**, we needed to check:
#
# 1) **Atomicity** – Each column should contain only one value.
# 2) **No Repeating Groups** – No multiple values stored in a single field.
#
# #### **SQL Query to Check 1NF Compliance:**
#
# SELECT OrderID, CustomerID, ProductID, OrderDate, ReturnDate, Quantity, TotalPrice, PaymentMethod, OrderStatus FROM Orders;
#
# ![][image77]
# ![][image78]
#
# **Output Received:**
#
# ![][image79]
# ![][image80]
#
# **Observations:** Since every value is atomic (single-valued), it is **already in 1NF**.
#
# **Interpreting the Results:**
#
# The dataset was analyzed, and it was found to already comply with First Normal Form (1NF), meaning all attributes contain atomic values and no repeating groups exist.
#
# Therefore, No further normalization is needed for 1NF.
#
# ![][image81]
#
# - When checking if the relationships between tables comply with First Normal Form (1NF).
#
# 1NF ensures that:
#
# - Each column contains atomic (indivisible) values.
# - There are no repeating groups or arrays.
# - Each row has a unique identifier (Primary Key).
# - If the relationships are already in 1NF, no further normalization is needed.
#
# ### **→ Identify the Tables and Their Structures**
#
# The following SQL command was used to view the structure of each table:
#
# ![][image82]
#
# This query helps verify if any table has columns that might contain multiple values.
#
# \-- Display the structure of the Orders table to check column types.
# DESC Orders;
#
# **Output Received:**
#
# ![][image83]
#
# **SQL Commands Executed:** To display the structure of the Products table to check if columns store atomic values.
# DESC Products;
#
# ![][image84]
#
# **Output Received:**
#
# ![][image85]
#
# **SQL Commands Executed:**
# To display the structure of the Suppliers table to verify proper relationships.
# DESC Suppliers;
# ![][image86]
# **Output Received:**
#
# ![][image87]
#
# ### **→ Checking for Repeating Groups**
#
# This query checks if any column contains **comma-separated values**, which indicate **non-atomic data**.
#
# **Purpose:**
#
# * Ensures that all columns contain atomic values (single, indivisible values).
# * If the query returns **rows where ProductID has multiple values**, it means **1NF is violated** and needs fixing.
#
# **SQL Query Executed:**
#
# **![][image88]**
#
# **If any column stores multiple values (e.g., ProductID as "3,4,5"), it violates 1NF.**
#
# **Output Received:**
#
# ![][image89]
#
# ### **→ Ensure Each Table Has a Primary Key**
#
# Every table in **1NF** must have a **Primary Key** to ensure **uniqueness**.
#
# 1) To check if the Orders table has a Primary Key.
#
# **SQL Query Executed:** SHOW KEYS FROM Orders WHERE Key\_name \= 'PRIMARY';
#
# ![][image90]
#
# **Output Received:**
#
# ![][image91]
#
# 2) To  check if the Customers table has a Primary Key.
#
# **SQL Query Executed:** SHOW KEYS FROM Customers WHERE Key\_name \= 'PRIMARY';
#
# ![][image92]
#
# **Output Received:**
#
# ![][image93]
#
# 3) To check if the Products table has a Primary Key.
#
# **SQL Query Executed:** SHOW KEYS FROM Products WHERE Key\_name \= 'PRIMARY';
#
# ![][image94]
#
# **Output Received:**
#
# ![][image95]
#
#  **Purpose:** If any table does **not** have a Primary Key, it is **not in 1NF**.
#
# ### **→ Check for Data Atomicity**
#
# Verifies that all values in columns are **single (atomic) values**.
#
# → To check if any column has multiple words or values stored together.
#
#  **SQL Query Executed :** SELECT CustomerID, PurchaseHistory FROM Customers WHERE PurchaseHistory LIKE '% %'; \-- Identifies fields with multiple values stored in one column.
#
# ![][image96]
#
# **Output Received:**
#
# ![][image97]
#
# ![][image98]
#
# **Purpose:** If `PurchaseHistory` stores multiple products in one field instead of separate rows, it **violates 1NF**.
#
# ### **→ Verify If the Data is Already in 1NF**
#
# If the previous queries return **no violations**, then **the database is already in 1NF**.
#
# → To display a few records from the Orders table to confirm atomicity.
#
# **SQL Query Executed:** SELECT \* FROM Orders LIMIT 10;
#
# ![][image99]
#
# **Output Received:**
#
# **![][image100]**
#
# → To display a few records from the Products table to confirm no multi-valued attributes exist.
#
# **SQL Query Executed:** SELECT \* FROM Products LIMIT 10;
#
# **![][image101]**
#
# **Output Received:**
#
# ![][image102]
#
# **Purpose:** A quick review to confirm that no column contains **multiple values in one field**.
#
# ---
#
# ### **Final Confirmation**
#
# All tests confirm that the database is already in **1NF**:
# Observation:
#
# * The database is already in First Normal Form (1NF).
# * All attributes contain atomic values, there are no repeating groups, and every table has a primary key.
# * No further normalization is required for 1NF
#
# [image1]: <data:image/png;base64,...>
#
# [image2]: <data:image/png;base64,...>
#
# [image3]: <data:image/png;base64,...>
#
# [image4]: <data:image/png;base64,...>
#
# [image5]: <data:image/png;base64,...>
#
# [image6]: <data:image/png;base64,...>
#
# [image7]: <data:image/png;base64,...>
#
# [image8]: <data:image/png;base64,...>
#
# [image9]: <data:image/png;base64,...>
#
# [image10]: <data:image/png;base64,...>
#
# [image11]: <data:image/png;base64,...>
#
# [image12]: <data:image/png;base64,...>
#
# [image13]: <data:image/png;base64,...>
#
# [image14]: <data:image/png;base64,...>
#
# [image15]: <data:image/png;base64,...>
#
# [image16]: <data:image/png;base64,...>
#
# [image17]: <data:image/png;base64,...>
#
# [image18]: <data:image/png;base64,...>
#
# [image19]: <data:image/png;base64,...>
#
# [image20]: <data:image/png;base64,...>
#
# [image21]: <data:image/png;base64,...>
#
# [image22]: <data:image/png;base64,...>
#
# [image23]: <data:image/png;base64,...>
#
# [image24]: <data:image/png;base64,...>
#
# [image25]: <data:image/png;base64,...>
#
# [image26]: <data:image/png;base64,...>
#
# [image27]: <data:image/png;base64,...>
#
# [image28]: <data:image/png;base64,...>
#
# [image29]: <data:image/png;base64,...>
#
# [image30]: <data:image/png;base64,...>
#
# [image31]: <data:image/png;base64,...>
#
# [image32]: <data:image/png;base64,...>
#
# [image33]: <data:image/png;base64,...>
#
# [image34]: <data:image/png;base64,...>
#
# [image35]: <data:image/png;base64,...>
#
# [image36]: <data:image/png;base64,...>
#
# [image37]: <data:image/png;base64,...>
#
# [image38]: <data:image/png;base64,...>
#
# [image39]: <data:image/png;base64,...>
#
# [image40]: <data:image/png;base64,...>
#
# [image41]: <data:image/png;base64,...>
#
# [image42]: <data:image/png;base64,...>
#
# [image43]: <data:image/png;base64,...>
#
# [image44]: <data:image/png;base64,...>
#
# [image45]: <data:image/png;base64,...>
#
# [image46]: <data:image/png;base64,...>
#
# [image47]: <data:image/png;base64,...>
#
# [image48]: <data:image/png;base64,...>
#
# [image49]: <data:image/png;base64,...>
#
# [image50]: <data:image/png;base64,...>
#
# [image51]: <data:image/png;base64,...>
#
# [image52]: <data:image/png;base64,...>
#
# [image53]: <data:image/png;base64,...>
#
# [image54]: <data:image/png;base64,...>
#
# [image55]: <data:image/png;base64,...>
#
# [image56]: <data:image/png;base64,...>
#
# [image57]: <data:image/png;base64,...>
#
# [image58]: <data:image/png;base64,...>
#
# [image59]: <data:image/png;base64,...>
#
# [image60]: <data:image/png;base64,...>
#
# [image61]: <data:image/png;base64,...>
#
# [image62]: <data:image/png;base64,...>
#
# [image63]: <data:image/png;base64,...>
#
# [image64]: <data:image/png;base64,...>
#
# [image65]: <data:image/png;base64,...>
#
# [image66]: <data:image/png;base64,...>
#
# [image67]: <data:image/png;base64,...>
#
# [image68]: <data:image/png;base64,...>
#
# [image69]: <data:image/png;base64,...>
#
# [image70]: <data:image/png;base64,...>
#
# [image71]: <data:image/png;base64,...>
#
# [image72]: <data:image/png;base64,...>
#
# [image73]: <data:image/png;base64,...>
#
# [image74]: <data:image/png;base64,...>
#
# [image75]: <data:image/png;base64,...>
#
# [image76]: <data:image/png;base64,...>
#
# [image77]: <data:image/png;base64,...>
#
# [image78]: <data:image/png;base64,...>
#
# [image79]: <data:image/png;base64,...>
#
# [image80]: <data:image/png;base64,...>
#
# [image81]: <data:image/png;base64,...>
#
# [image82]: <data:image/png;base64,...>
#
# [image83]: <data:image/png;base64,...>
#
# [image84]: <data:image/png;base64,...>
#
# [image85]: <data:image/png;base64,...>
#
# [image86]: <data:image/png;base64,...>
#
# [image87]: <data:image/png;base64,...>
#
# [image88]: <data:image/png;base64,...>
#
# [image89]: <data:image/png;base64,...>
#
# [image90]: <data:image/png;base64,...>
#
# [image91]: <data:image/png;base64,...>
#
# [image92]: <data:image/png;base64,...>
#
# [image93]: <data:image/png;base64,...>
#
# [image94]: <data:image/png;base64,...>
#
# [image95]: <data:image/png;base64,...>
#
# [image96]: <data:image/png;base64,...>
#
# [image97]: <data:image/png;base64,...>
#
# [image98]: <data:image/png;base64,...>
#
# [image99]: <data:image/png;base64,...>
#
# [image100]: <data:image/png;base64,...>
#
# [image101]: <data:image/png;base64,...>
#
# [image102]: <data:image/png;base64,...>
